# %% [markdown]
# ### Objective
#
# In this notebook, we investigate the Bayesian optimization strategy for PE optimization.
#
# We consider multiple Qs as design specification.

# %%
import copy
import time
import pickle
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler 
from scipy.stats import qmc, norm
import gpflow
from sklearn.metrics import brier_score_loss

import utility
from two_sources import thermal_distribution_maxT
from manager import region_manager

# %% [markdown]
# ### 0. Setup necessary constants

# %%
df_Q = pd.read_csv('./dataset/Q_test_locations.csv')

# %%
Tjmax = 175

# Bounds: d, b, L, c, L_duct, n
lb = np.array([5e-3, 73.7e-3, 127.2e-3, 10e-3, 20e-3, 10])
ub = np.array([30e-3, 307e-3, 530e-3, 39e-3, 50e-3, 50])
Data = (25, 50e-3, 65e-3, 61.4e-3, 106e-3)

# %% [markdown]
# ### 1. Load dataset

# %%
df_train = pd.read_csv('./dataset/passive_learning_train.csv')
df_train.columns = ['Q1', 'Q2', 'd', 'b', 'L', 'c', 'L_duct', 'n', 't', 'xc1', 'yc1', 'xc2', 'yc2', 'Tc', 'Tj', 'w']
print(f"Training pool: {df_train.shape[0]}")
# Out:
# Training pool: 939

# %%
df_candidates = pd.read_csv('./dataset/candidates.csv')
df_candidates.columns = ['d', 'b', 'L', 'c', 'L_duct', 'n', 't', 'xc1', 'yc1', 'xc2', 'yc2']
print(f"Candidate pool: {df_candidates.shape[0]}")
# Out:
# Candidate pool: 470070

# %%
# Dedicated testing set
df_test = pd.read_csv('./dataset/test.csv')
df_test.columns = ['Q1', 'Q2', 'd', 'b', 'L', 'c', 'L_duct', 'n', 't', 'xc1', 'yc1', 'xc2', 'yc2', 'Tc', 'Tj', 'w']
print(f"Testing dataset: {df_test.shape[0]}")
# Out:
# Testing dataset: 5655

# %%
# Extract train data
X, _, y, _ = utility.create_samples(df_train, 200)
X_test, _, y_test, _ = utility.create_samples(df_test, len(df_test))

# Normalization
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# ### 2. BO iterations

# %% [markdown]
# #### 2.1 Initial training

# %%
# %%time

X_train = copy.deepcopy(X)
X_train_scaled = copy.deepcopy(X_scaled)
y_train = copy.deepcopy(y)

GP = utility.fit(X_train_scaled, y_train, n_restarts=10, trainable=True, verbose=True)
# Out:
# Performing 1-th optimization:
# Performing 2-th optimization:
# Performing 3-th optimization:
# Performing 4-th optimization:
# Performing 5-th optimization:
# Performing 6-th optimization:
# Performing 7-th optimization:
# Performing 8-th optimization:
# Performing 9-th optimization:
# Performing 10-th optimization:
# CPU times: total: 29.2 s
# Wall time: 15 s

# %%
X_test_norm = scaler.transform(X_test)
f_mean, f_var = GP.predict_f(X_test_norm, full_cov=False)
y_prob = norm.cdf(175, loc=f_mean, scale=np.sqrt(f_var))
label = np.where(y_test > 175, 1, 0)
brier_score = brier_score_loss(label, 1-y_prob)
    
rmse, max_e, max_per, _, mean_per = utility.evaluate_model(y_test, f_mean.numpy().flatten())
print(f"RMSE: {rmse:.4f} / data std: {np.std(y_test):.4f}")
print(f"Max Error: {max_e:.4f}")
print(f"Max Percentage Error: {max_per:.2f}")
print(f"Mean Percentage Error: {mean_per:.2f}")
print(f"Brier score: {brier_score:.5f}")
# Out:
# RMSE: 12.4605 / data std: 32.8753
# Max Error: 168.8406
# Max Percentage Error: 58.90
# Mean Percentage Error: 7.07
# Brier score: 0.02489

# %% [markdown]
# #### 2.2 BO strategy specifications

# %%
def copy_model(GP):
    model = copy.deepcopy(GP)
    init_lengthscales = model.kernel.lengthscales.numpy().reshape(1, -1)
    init_variance = model.kernel.variance.numpy().flatten()[0]

    return model, init_lengthscales, init_variance

def propose_candidates(model, Q1, Q2, df_candidates, n_batch=10):
    # Compose dataset
    Q1_array = Q1*np.ones((df_candidates.shape[0], 1))
    Q2_array = Q2*np.ones((df_candidates.shape[0], 1))
    X_candidates = df_candidates.to_numpy()
    X_candidates = np.hstack((Q1_array, Q2_array, X_candidates))

    # Evaluate candidates
    f_mean, f_var = utility.GP_predict_candidates(model, X_candidates, scaler)

    # Select candidates
    acq, indices = utility.acquisition(None, f_mean, f_var, X_candidates, scaler, 
                                       Tjmax, batch_mode=True, batch_size=n_batch)
    print("Candidates selected!")

    return X_candidates, acq, indices

# %%
def create_managers(X_train, y_train, X_candidates, indices, Data, model,
                   n_batch, Tjmax, Q1, Q2):
    managers = []
    for index in indices:
        # Enrich dataset
        X_train = np.vstack((X_train, X_candidates[index]))
        y, _ = thermal_distribution_maxT(X_candidates[index], Data)
        y_train = np.append(y_train, np.array(y))
    
        # Create managers
        manager = region_manager(model, n_batch, Data, Tjmax, X_candidates[index], Q1, Q2)
        managers.append(manager)
    
        # Update weight
        if y <= manager.Tjmax:
            w = utility.evaluate_weight(X_candidates[index].reshape(1, -1))[0]
        else:
            w = np.inf
            
        manager.init_weight(w) 
    print("Managers created!")

    return managers, X_train, y_train

# %%
def branch_and_bound(X_train, y_train, init_lengthscales, init_variance, 
                     managers, indices, lb, ub, scaler):

    n_batch = len(managers)
    
    # Branch and bound
    counter = 0
    status_list = [False] * n_batch
    design_list, weight_list = [], []

    while np.sum(status_list) < n_batch:
        counter += 1
        print(f"Start {counter}-th iteration:")
    
        # Update global GP model
        X_train_scaled = scaler.transform(X_train)
        model = utility.fit(X_train_scaled, y_train, n_restarts=1, init_lengthscales=init_lengthscales.flatten(), 
                            init_variance=init_variance, trainable=False, verbose=False)
        print("Global model updated!")
        
        for i, (manager, index) in enumerate(zip(managers, indices)):
            print(f"Process {i+1}/{n_batch} manager:")
            print("Updating manager model:")
            manager.update_model(model)
            
            if not manager.converge_flag:
                X, y = manager.branch_and_bound(lb, ub, scaler, candidate_num=5000)
                X_train = np.vstack((X_train, X))
                y_train = np.append(y_train, np.array(y))
        
                # 5-Check conditions
                design, weight, converge_flag = manager.check_converge()   
                status_list[i] = converge_flag
    
                if design is not None:
                    design_list.append(design)
                    weight_list.append(weight)
                    print(f"{i+1}/{n_batch} manager done!")
            else:
                print(f"Skip {i+1}/{n_batch} manager.")

    print(f"All managers done!")

    return design_list, weight_list

# %%
def parse_results(design_list, weight_list, Data):
    best_weight = np.min(weight_list)
    best_design = design_list[np.argmin(weight_list)]
    Tmax, _ = thermal_distribution_maxT(best_design, Data)

    return best_weight, best_design[2:], Tmax

# %%
def BO_run(X_train, y_train, GP, Q1, Q2, df_candidates, n_batch, 
           Data, lb, ub, scaler):
    # Init model
    model, init_lengthscales, init_variance = copy_model(GP)

    # Propose candidates
    X_candidates, acq, indices = propose_candidates(model, Q1, Q2, df_candidates, n_batch)

    # Set up managers (and enrich dataset)
    managers, X_train, y_train = create_managers(X_train, y_train, X_candidates, indices, 
                                                 Data, model, n_batch, Tjmax, Q1, Q2)

    # Branch and bound algorithm
    designs, weights = branch_and_bound(X_train, y_train, init_lengthscales, init_variance, 
                                        managers, indices, lb, ub, scaler)

    # Parse results
    best_weight, best_design, Tmax = parse_results(designs, weights, Data)

    return best_weight, best_design, Tmax

# %% [markdown]
# ### 3. Multip Qs

# %%
n_batch = 10
best_designs = []
best_weights = []
best_Tmaxs = []
runtimes = []
for i, (Q1, Q2) in enumerate(df_Q.to_numpy()[:2]):
    print(f"Processing {i+1}th iteration with Q1 ({Q1:.2f}) & Q2 ({Q2:2f}) combinations:")
    start = time.time()
    best_weight, best_design, Tmax = BO_run(X_train, y_train, GP, Q1, Q2, 
                                            df_candidates, n_batch, Data, lb, ub, 
                                            scaler)
    end = time.time()
    best_designs.append(best_design)
    best_weights.append(best_weight)
    best_Tmaxs.append(Tmax)
    runtimes.append(end-start)
# Out:
# Processing 1th iteration with Q1 (324.55) & Q2 (273.426620) combinations:
# Select candidates==>
# ==> Complete candidates selection.
# Candidates selected!
# Managers created!
# Start 1-th iteration:
# Global model updated!
# Process 1/10 manager:
# Updating manager model:
# Generated 1094 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Process 2/10 manager:
# Updating manager model:
# Generated 4999 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Process 3/10 manager:
# Updating manager model:
# Generated 1531 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Process 4/10 manager:
# Updating manager model:
# Generated 3132 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Process 5/10 manager:
# Updating manager model:
# Generated 2139 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# 5/10 manager done!
# Process 6/10 manager:
# Updating manager model:
# Generated 4994 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Process 7/10 manager:
# Updating manager model:
# Generated 5000 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Process 8/10 manager:
# Updating manager model:
# Generated 4986 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Process 9/10 manager:
# Updating manager model:
# Generated 4995 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Process 10/10 manager:
# Updating manager model:
# Generated 1994 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Start 2-th iteration:
# Global model updated!
# Process 1/10 manager:
# Updating manager model:
# Generated 1403 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Process 2/10 manager:
# Updating manager model:
# Generated 4985 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Process 3/10 manager:
# Updating manager model:
# Generated 2726 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# 3/10 manager done!
# Process 4/10 manager:
# Updating manager model:
# Generated 3501 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# 4/10 manager done!
# Process 5/10 manager:
# Updating manager model:
# Skip 5/10 manager.
# Process 6/10 manager:
# Updating manager model:
# Generated 4957 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# 6/10 manager done!
# Process 7/10 manager:
# Updating manager model:
# Generated 4981 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Process 8/10 manager:
# Updating manager model:
# Generated 4943 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Process 9/10 manager:
# Updating manager model:
# Generated 4954 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Process 10/10 manager:
# Updating manager model:
# Generated 2321 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Start 3-th iteration:
# Global model updated!
# Process 1/10 manager:
# Updating manager model:
# Generated 1910 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Process 2/10 manager:
# Updating manager model:
# Generated 4886 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Process 3/10 manager:
# Updating manager model:
# Skip 3/10 manager.
# Process 4/10 manager:
# Updating manager model:
# Skip 4/10 manager.
# Process 5/10 manager:
# Updating manager model:
# Skip 5/10 manager.
# Process 6/10 manager:
# Updating manager model:
# Skip 6/10 manager.
# Process 7/10 manager:
# Updating manager model:
# Generated 4844 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Process 8/10 manager:
# Updating manager model:
# Generated 4556 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Process 9/10 manager:
# Updating manager model:
# Generated 4916 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# 9/10 manager done!
# Process 10/10 manager:
# Updating manager model:
# Generated 2670 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Start 4-th iteration:
# Global model updated!
# Process 1/10 manager:
# Updating manager model:
# Generated 1740 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Process 2/10 manager:
# Updating manager model:
# Generated 4096 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Process 3/10 manager:
# Updating manager model:
# Skip 3/10 manager.
# Process 4/10 manager:
# Updating manager model:
# Skip 4/10 manager.
# Process 5/10 manager:
# Updating manager model:
# Skip 5/10 manager.
# Process 6/10 manager:
# Updating manager model:
# Skip 6/10 manager.
# Process 7/10 manager:
# Updating manager model:
# Generated 3835 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Process 8/10 manager:
# Updating manager model:
# Generated 3105 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Process 9/10 manager:
# Updating manager model:
# Skip 9/10 manager.
# Process 10/10 manager:
# Updating manager model:
# Generated 3332 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Start 5-th iteration:
# Global model updated!
# Process 1/10 manager:
# Updating manager model:
# Generated 1992 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Process 2/10 manager:
# Updating manager model:
# Generated 3670 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Process 3/10 manager:
# Updating manager model:
# Skip 3/10 manager.
# Process 4/10 manager:
# Updating manager model:
# Skip 4/10 manager.
# Process 5/10 manager:
# Updating manager model:
# Skip 5/10 manager.
# Process 6/10 manager:
# Updating manager model:
# Skip 6/10 manager.
# Process 7/10 manager:
# Updating manager model:
# Generated 3571 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# 7/10 manager done!
# Process 8/10 manager:
# Updating manager model:
# Generated 2619 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# 8/10 manager done!
# Process 9/10 manager:
# Updating manager model:
# Skip 9/10 manager.
# Process 10/10 manager:
# Updating manager model:
# Generated 2155 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Start 6-th iteration:
# Global model updated!
# Process 1/10 manager:
# Updating manager model:
# Generated 2594 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Process 2/10 manager:
# Updating manager model:
# Generated 1932 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# 2/10 manager done!
# Process 3/10 manager:
# Updating manager model:
# Skip 3/10 manager.
# Process 4/10 manager:
# Updating manager model:
# Skip 4/10 manager.
# Process 5/10 manager:
# Updating manager model:
# Skip 5/10 manager.
# Process 6/10 manager:
# Updating manager model:
# Skip 6/10 manager.
# Process 7/10 manager:
# Updating manager model:
# Skip 7/10 manager.
# Process 8/10 manager:
# Updating manager model:
# Skip 8/10 manager.
# Process 9/10 manager:
# Updating manager model:
# Skip 9/10 manager.
# Process 10/10 manager:
# Updating manager model:
# Generated 1762 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Start 7-th iteration:
# Global model updated!
# Process 1/10 manager:
# Updating manager model:
# Generated 1345 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# 1/10 manager done!
# Process 2/10 manager:
# Updating manager model:
# Skip 2/10 manager.
# Process 3/10 manager:
# Updating manager model:
# Skip 3/10 manager.
# Process 4/10 manager:
# Updating manager model:
# Skip 4/10 manager.
# Process 5/10 manager:
# Updating manager model:
# Skip 5/10 manager.
# Process 6/10 manager:
# Updating manager model:
# Skip 6/10 manager.
# Process 7/10 manager:
# Updating manager model:
# Skip 7/10 manager.
# Process 8/10 manager:
# Updating manager model:
# Skip 8/10 manager.
# Process 9/10 manager:
# Updating manager model:
# Skip 9/10 manager.
# Process 10/10 manager:
# Updating manager model:
# Generated 2642 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Start 8-th iteration:
# Global model updated!
# Process 1/10 manager:
# Updating manager model:
# Skip 1/10 manager.
# Process 2/10 manager:
# Updating manager model:
# Skip 2/10 manager.
# Process 3/10 manager:
# Updating manager model:
# Skip 3/10 manager.
# Process 4/10 manager:
# Updating manager model:
# Skip 4/10 manager.
# Process 5/10 manager:
# Updating manager model:
# Skip 5/10 manager.
# Process 6/10 manager:
# Updating manager model:
# Skip 6/10 manager.
# Process 7/10 manager:
# Updating manager model:
# Skip 7/10 manager.
# Process 8/10 manager:
# Updating manager model:
# Skip 8/10 manager.
# Process 9/10 manager:
# Updating manager model:
# Skip 9/10 manager.
# Process 10/10 manager:
# Updating manager model:
# Generated 2911 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Start 9-th iteration:
# Global model updated!
# Process 1/10 manager:
# Updating manager model:
# Skip 1/10 manager.
# Process 2/10 manager:
# Updating manager model:
# Skip 2/10 manager.
# Process 3/10 manager:
# Updating manager model:
# Skip 3/10 manager.
# Process 4/10 manager:
# Updating manager model:
# Skip 4/10 manager.
# Process 5/10 manager:
# Updating manager model:
# Skip 5/10 manager.
# Process 6/10 manager:
# Updating manager model:
# Skip 6/10 manager.
# Process 7/10 manager:
# Updating manager model:
# Skip 7/10 manager.
# Process 8/10 manager:
# Updating manager model:
# Skip 8/10 manager.
# Process 9/10 manager:
# Updating manager model:
# Skip 9/10 manager.
# Process 10/10 manager:
# Updating manager model:
# Generated 2817 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Start 10-th iteration:
# Global model updated!
# Process 1/10 manager:
# Updating manager model:
# Skip 1/10 manager.
# Process 2/10 manager:
# Updating manager model:
# Skip 2/10 manager.
# Process 3/10 manager:
# Updating manager model:
# Skip 3/10 manager.
# Process 4/10 manager:
# Updating manager model:
# Skip 4/10 manager.
# Process 5/10 manager:
# Updating manager model:
# Skip 5/10 manager.
# Process 6/10 manager:
# Updating manager model:
# Skip 6/10 manager.
# Process 7/10 manager:
# Updating manager model:
# Skip 7/10 manager.
# Process 8/10 manager:
# Updating manager model:
# Skip 8/10 manager.
# Process 9/10 manager:
# Updating manager model:
# Skip 9/10 manager.
# Process 10/10 manager:
# Updating manager model:
# Generated 3929 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Start 11-th iteration:
# Global model updated!
# Process 1/10 manager:
# Updating manager model:
# Skip 1/10 manager.
# Process 2/10 manager:
# Updating manager model:
# Skip 2/10 manager.
# Process 3/10 manager:
# Updating manager model:
# Skip 3/10 manager.
# Process 4/10 manager:
# Updating manager model:
# Skip 4/10 manager.
# Process 5/10 manager:
# Updating manager model:
# Skip 5/10 manager.
# Process 6/10 manager:
# Updating manager model:
# Skip 6/10 manager.
# Process 7/10 manager:
# Updating manager model:
# Skip 7/10 manager.
# Process 8/10 manager:
# Updating manager model:
# Skip 8/10 manager.
# Process 9/10 manager:
# Updating manager model:
# Skip 9/10 manager.
# Process 10/10 manager:
# Updating manager model:
# Generated 2735 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Start 12-th iteration:
# Global model updated!
# Process 1/10 manager:
# Updating manager model:
# Skip 1/10 manager.
# Process 2/10 manager:
# Updating manager model:
# Skip 2/10 manager.
# Process 3/10 manager:
# Updating manager model:
# Skip 3/10 manager.
# Process 4/10 manager:
# Updating manager model:
# Skip 4/10 manager.
# Process 5/10 manager:
# Updating manager model:
# Skip 5/10 manager.
# Process 6/10 manager:
# Updating manager model:
# Skip 6/10 manager.
# Process 7/10 manager:
# Updating manager model:
# Skip 7/10 manager.
# Process 8/10 manager:
# Updating manager model:
# Skip 8/10 manager.
# Process 9/10 manager:
# Updating manager model:
# Skip 9/10 manager.
# Process 10/10 manager:
# Updating manager model:
# Generated 2012 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Start 13-th iteration:
# Global model updated!
# Process 1/10 manager:
# Updating manager model:
# Skip 1/10 manager.
# Process 2/10 manager:
# Updating manager model:
# Skip 2/10 manager.
# Process 3/10 manager:
# Updating manager model:
# Skip 3/10 manager.
# Process 4/10 manager:
# Updating manager model:
# Skip 4/10 manager.
# Process 5/10 manager:
# Updating manager model:
# Skip 5/10 manager.
# Process 6/10 manager:
# Updating manager model:
# Skip 6/10 manager.
# Process 7/10 manager:
# Updating manager model:
# Skip 7/10 manager.
# Process 8/10 manager:
# Updating manager model:
# Skip 8/10 manager.
# Process 9/10 manager:
# Updating manager model:
# Skip 9/10 manager.
# Process 10/10 manager:
# Updating manager model:
# Generated 2849 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Start 14-th iteration:
# Global model updated!
# Process 1/10 manager:
# Updating manager model:
# Skip 1/10 manager.
# Process 2/10 manager:
# Updating manager model:
# Skip 2/10 manager.
# Process 3/10 manager:
# Updating manager model:
# Skip 3/10 manager.
# Process 4/10 manager:
# Updating manager model:
# Skip 4/10 manager.
# Process 5/10 manager:
# Updating manager model:
# Skip 5/10 manager.
# Process 6/10 manager:
# Updating manager model:
# Skip 6/10 manager.
# Process 7/10 manager:
# Updating manager model:
# Skip 7/10 manager.
# Process 8/10 manager:
# Updating manager model:
# Skip 8/10 manager.
# Process 9/10 manager:
# Updating manager model:
# Skip 9/10 manager.
# Process 10/10 manager:
# Updating manager model:
# Generated 1655 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Start 15-th iteration:
# Global model updated!
# Process 1/10 manager:
# Updating manager model:
# Skip 1/10 manager.
# Process 2/10 manager:
# Updating manager model:
# Skip 2/10 manager.
# Process 3/10 manager:
# Updating manager model:
# Skip 3/10 manager.
# Process 4/10 manager:
# Updating manager model:
# Skip 4/10 manager.
# Process 5/10 manager:
# Updating manager model:
# Skip 5/10 manager.
# Process 6/10 manager:
# Updating manager model:
# Skip 6/10 manager.
# Process 7/10 manager:
# Updating manager model:
# Skip 7/10 manager.
# Process 8/10 manager:
# Updating manager model:
# Skip 8/10 manager.
# Process 9/10 manager:
# Updating manager model:
# Skip 9/10 manager.
# Process 10/10 manager:
# Updating manager model:
# Generated 1213 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Start 16-th iteration:
# Global model updated!
# Process 1/10 manager:
# Updating manager model:
# Skip 1/10 manager.
# Process 2/10 manager:
# Updating manager model:
# Skip 2/10 manager.
# Process 3/10 manager:
# Updating manager model:
# Skip 3/10 manager.
# Process 4/10 manager:
# Updating manager model:
# Skip 4/10 manager.
# Process 5/10 manager:
# Updating manager model:
# Skip 5/10 manager.
# Process 6/10 manager:
# Updating manager model:
# Skip 6/10 manager.
# Process 7/10 manager:
# Updating manager model:
# Skip 7/10 manager.
# Process 8/10 manager:
# Updating manager model:
# Skip 8/10 manager.
# Process 9/10 manager:
# Updating manager model:
# Skip 9/10 manager.
# Process 10/10 manager:
# Updating manager model:
# Generated 2317 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Start 17-th iteration:
# Global model updated!
# Process 1/10 manager:
# Updating manager model:
# Skip 1/10 manager.
# Process 2/10 manager:
# Updating manager model:
# Skip 2/10 manager.
# Process 3/10 manager:
# Updating manager model:
# Skip 3/10 manager.
# Process 4/10 manager:
# Updating manager model:
# Skip 4/10 manager.
# Process 5/10 manager:
# Updating manager model:
# Skip 5/10 manager.
# Process 6/10 manager:
# Updating manager model:
# Skip 6/10 manager.
# Process 7/10 manager:
# Updating manager model:
# Skip 7/10 manager.
# Process 8/10 manager:
# Updating manager model:
# Skip 8/10 manager.
# Process 9/10 manager:
# Updating manager model:
# Skip 9/10 manager.
# Process 10/10 manager:
# Updating manager model:
# Generated 1699 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Start 18-th iteration:
# Global model updated!
# Process 1/10 manager:
# Updating manager model:
# Skip 1/10 manager.
# Process 2/10 manager:
# Updating manager model:
# Skip 2/10 manager.
# Process 3/10 manager:
# Updating manager model:
# Skip 3/10 manager.
# Process 4/10 manager:
# Updating manager model:
# Skip 4/10 manager.
# Process 5/10 manager:
# Updating manager model:
# Skip 5/10 manager.
# Process 6/10 manager:
# Updating manager model:
# Skip 6/10 manager.
# Process 7/10 manager:
# Updating manager model:
# Skip 7/10 manager.
# Process 8/10 manager:
# Updating manager model:
# Skip 8/10 manager.
# Process 9/10 manager:
# Updating manager model:
# Skip 9/10 manager.
# Process 10/10 manager:
# Updating manager model:
# Generated 2339 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Start 19-th iteration:
# Global model updated!
# Process 1/10 manager:
# Updating manager model:
# Skip 1/10 manager.
# Process 2/10 manager:
# Updating manager model:
# Skip 2/10 manager.
# Process 3/10 manager:
# Updating manager model:
# Skip 3/10 manager.
# Process 4/10 manager:
# Updating manager model:
# Skip 4/10 manager.
# Process 5/10 manager:
# Updating manager model:
# Skip 5/10 manager.
# Process 6/10 manager:
# Updating manager model:
# Skip 6/10 manager.
# Process 7/10 manager:
# Updating manager model:
# Skip 7/10 manager.
# Process 8/10 manager:
# Updating manager model:
# Skip 8/10 manager.
# Process 9/10 manager:
# Updating manager model:
# Skip 9/10 manager.
# Process 10/10 manager:
# Updating manager model:
# Generated 1804 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# 10/10 manager done!
# All managers done!
# Processing 2th iteration with Q1 (332.35) & Q2 (70.869323) combinations:
# Select candidates==>
# ==> Complete candidates selection.
# Candidates selected!
# Managers created!
# Start 1-th iteration:
# Global model updated!
# Process 1/10 manager:
# Updating manager model:
# Generated 3099 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Process 2/10 manager:
# Updating manager model:
# Generated 2167 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Process 3/10 manager:
# Updating manager model:
# Generated 4999 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Process 4/10 manager:
# Updating manager model:
# Generated 4997 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Process 5/10 manager:
# Updating manager model:
# Generated 5000 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Process 6/10 manager:
# Updating manager model:
# Generated 4998 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Process 7/10 manager:
# Updating manager model:
# Generated 4993 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Process 8/10 manager:
# Updating manager model:
# Generated 1227 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Process 9/10 manager:
# Updating manager model:
# Generated 2517 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Process 10/10 manager:
# Updating manager model:
# Generated 2162 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# 10/10 manager done!
# Start 2-th iteration:
# Global model updated!
# Process 1/10 manager:
# Updating manager model:
# Generated 3190 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Process 2/10 manager:
# Updating manager model:
# Generated 1924 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Process 3/10 manager:
# Updating manager model:
# Generated 4996 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Process 4/10 manager:
# Updating manager model:
# Generated 4966 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Process 5/10 manager:
# Updating manager model:
# Generated 5000 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Process 6/10 manager:
# Updating manager model:
# Generated 4983 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Process 7/10 manager:
# Updating manager model:
# Generated 4988 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Process 8/10 manager:
# Updating manager model:
# Generated 1109 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Process 9/10 manager:
# Updating manager model:
# Generated 1479 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Process 10/10 manager:
# Updating manager model:
# Skip 10/10 manager.
# Start 3-th iteration:
# Global model updated!
# Process 1/10 manager:
# Updating manager model:
# Generated 1735 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# 1/10 manager done!
# Process 2/10 manager:
# Updating manager model:
# Generated 2860 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# 2/10 manager done!
# Process 3/10 manager:
# Updating manager model:
# Generated 4990 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# 3/10 manager done!
# Process 4/10 manager:
# Updating manager model:
# Generated 4871 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# 4/10 manager done!
# Process 5/10 manager:
# Updating manager model:
# Generated 4987 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Process 6/10 manager:
# Updating manager model:
# Generated 4809 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Process 7/10 manager:
# Updating manager model:
# Generated 4887 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# 7/10 manager done!
# Process 8/10 manager:
# Updating manager model:
# Generated 2434 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Process 9/10 manager:
# Updating manager model:
# Generated 3296 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Process 10/10 manager:
# Updating manager model:
# Skip 10/10 manager.
# Start 4-th iteration:
# Global model updated!
# Process 1/10 manager:
# Updating manager model:
# Skip 1/10 manager.
# Process 2/10 manager:
# Updating manager model:
# Skip 2/10 manager.
# Process 3/10 manager:
# Updating manager model:
# Skip 3/10 manager.
# Process 4/10 manager:
# Updating manager model:
# Skip 4/10 manager.
# Process 5/10 manager:
# Updating manager model:
# Generated 4366 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Process 6/10 manager:
# Updating manager model:
# Generated 3597 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Process 7/10 manager:
# Updating manager model:
# Skip 7/10 manager.
# Process 8/10 manager:
# Updating manager model:
# Generated 1854 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# 8/10 manager done!
# Process 9/10 manager:
# Updating manager model:
# Generated 4226 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Process 10/10 manager:
# Updating manager model:
# Skip 10/10 manager.
# Start 5-th iteration:
# Global model updated!
# Process 1/10 manager:
# Updating manager model:
# Skip 1/10 manager.
# Process 2/10 manager:
# Updating manager model:
# Skip 2/10 manager.
# Process 3/10 manager:
# Updating manager model:
# Skip 3/10 manager.
# Process 4/10 manager:
# Updating manager model:
# Skip 4/10 manager.
# Process 5/10 manager:
# Updating manager model:
# Generated 2665 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Process 6/10 manager:
# Updating manager model:
# Generated 1909 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# 6/10 manager done!
# Process 7/10 manager:
# Updating manager model:
# Skip 7/10 manager.
# Process 8/10 manager:
# Updating manager model:
# Skip 8/10 manager.
# Process 9/10 manager:
# Updating manager model:
# Generated 2258 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# 9/10 manager done!
# Process 10/10 manager:
# Updating manager model:
# Skip 10/10 manager.
# Start 6-th iteration:
# Global model updated!
# Process 1/10 manager:
# Updating manager model:
# Skip 1/10 manager.
# Process 2/10 manager:
# Updating manager model:
# Skip 2/10 manager.
# Process 3/10 manager:
# Updating manager model:
# Skip 3/10 manager.
# Process 4/10 manager:
# Updating manager model:
# Skip 4/10 manager.
# Process 5/10 manager:
# Updating manager model:
# Generated 3559 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Process 6/10 manager:
# Updating manager model:
# Skip 6/10 manager.
# Process 7/10 manager:
# Updating manager model:
# Skip 7/10 manager.
# Process 8/10 manager:
# Updating manager model:
# Skip 8/10 manager.
# Process 9/10 manager:
# Updating manager model:
# Skip 9/10 manager.
# Process 10/10 manager:
# Updating manager model:
# Skip 10/10 manager.
# Start 7-th iteration:
# Global model updated!
# Process 1/10 manager:
# Updating manager model:
# Skip 1/10 manager.
# Process 2/10 manager:
# Updating manager model:
# Skip 2/10 manager.
# Process 3/10 manager:
# Updating manager model:
# Skip 3/10 manager.
# Process 4/10 manager:
# Updating manager model:
# Skip 4/10 manager.
# Process 5/10 manager:
# Updating manager model:
# Generated 2601 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# Process 6/10 manager:
# Updating manager model:
# Skip 6/10 manager.
# Process 7/10 manager:
# Updating manager model:
# Skip 7/10 manager.
# Process 8/10 manager:
# Updating manager model:
# Skip 8/10 manager.
# Process 9/10 manager:
# Updating manager model:
# Skip 9/10 manager.
# Process 10/10 manager:
# Updating manager model:
# Skip 10/10 manager.
# Start 8-th iteration:
# Global model updated!
# Process 1/10 manager:
# Updating manager model:
# Skip 1/10 manager.
# Process 2/10 manager:
# Updating manager model:
# Skip 2/10 manager.
# Process 3/10 manager:
# Updating manager model:
# Skip 3/10 manager.
# Process 4/10 manager:
# Updating manager model:
# Skip 4/10 manager.
# Process 5/10 manager:
# Updating manager model:
# Generated 3405 new candidates!
# Select candidates==>
# ==> Complete candidates selection.
# 5/10 manager done!
# Process 6/10 manager:
# Updating manager model:
# Skip 6/10 manager.
# Process 7/10 manager:
# Updating manager model:
# Skip 7/10 manager.
# Process 8/10 manager:
# Updating manager model:
# Skip 8/10 manager.
# Process 9/10 manager:
# Updating manager model:
# Skip 9/10 manager.
# Process 10/10 manager:
# Updating manager model:
# Skip 10/10 manager.
# All managers done!

# %%
df = pd.DataFrame({"Q1": df_Q.to_numpy()[:2, 0],
                  "Q2": df_Q.to_numpy()[:2, 1],
                   "weight": best_weights,
                   "Tmax": best_Tmaxs,
                  "Runtime": runtimes})
best_designs = np.array(best_designs)
for i, col in enumerate(['d', 'b', 'L', 'c', 'L_duct', 'n', 't', 'xc1', 'yc1', 'xc2', 'yc2']):
    df[col] = best_designs[:, i]

# %%
df
# Out:
#            Q1          Q2    weight        Tmax    Runtime         d  \
# 0  324.548857  273.426620  0.505090  165.899470  46.100153  0.005233
# 1  332.350489   70.869323  0.478799  167.778683  41.520903  0.005156
#
#           b         L         c    L_duct     n         t       xc1       yc1  \
# 0  0.077795  0.240320  0.019333  0.041938  11.0  0.001010  0.032526  0.059196
# 1  0.076075  0.254258  0.013660  0.031642  11.0  0.001046  0.041270  0.064787
#
#         xc2       yc2
# 0  0.038572  0.177734
# 1  0.031042  0.190260
